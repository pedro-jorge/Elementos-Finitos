# %%
import googleapiclient.discovery as d
import re

api_service_name = "youtube"
api_version = "v3"
api_key = "AIzaSyAn3hjX3AyYyhPCp4gdRqxoR3TwtsSj-Yo"

youtube = d.build(
    api_service_name,
    api_version,
    developerKey=api_key
)

video_url = "https://www.youtube.com/watch?v=X4wge_avH2s"
max_results = 50

# %%
def get_comment(response):
    return response["snippet"]["topLevelComment"]["snippet"]["textOriginal"]


def print_replies(response):
    try:
        n = len(response["replies"]["comments"])
        
        for i in range(n):
            print(response["replies"]["comments"][i]["snippet"]["textOriginal"])
    except:
        pass

# %%
def get_video_id(url):
    # Regular expression pattern to match a YouTube video ID
    pattern = r'(?:v=|\/)([0-9A-Za-z_-]{11}).*'
    
    # Search for the pattern in the URL
    match = re.search(pattern, url)
    
    # If a match is found, return the video ID
    if match:
        return match.group(1)
    else:
        return None
    
video_id = get_video_id(video_url)

# %%
request = youtube.commentThreads().list(
    part="id,replies,snippet",
    videoId=video_id,
    maxResults=max_results
)
response = request.execute()

for i in range(max_results):
    print(get_comment(response["items"][i]))
    print_replies(response["items"][i])
    
    print("")
    # for item in response["items"][i]["replies"]["comments"]:
    #     print(item["snippet"]["textOriginal"])
    #     print("")
# Out:
# Minha chave pix: dbsgproject@gmail.com
# As pessoas n tem ideia de quão trabalho é isso sério, absurdo dms , virei fã
# man uma ideia de edit que vcs podem tentar fazer no video de vcs é tentar fazer os personagens ou alguma coisa em vlta ficar se mechendo igual   eles faem nos raps de anime quando mostram uma cena de manga,
#  ja paguei vcs irmão!
# @@bernanribeiro3329 24 HORAS DE BERSERK (SAGA COMPLETA)
# não é completo?????
#  anyway, good job
# @@allandecastroferreira9359 , eu assitir só os filmes no yt, mas fiquei traumatizado por não ter a história completa. srsr; quero saber se esses 376 seria toda a história do mangá.
# Vc é incrível mano!
#
# 10:34:45
#
# muito bom mano trabalho excelente
#
# 8:22:30
#
# 2:32:14
#
# 3:40:00
#
# Foi uma semana e meia assistindo essa saga, muito obirgado pelo vídeo, foi uma jornada maravilhosa e parabéns pelo todo trabalho.
#
# ...
